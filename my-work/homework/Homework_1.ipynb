# %% [markdown]
# I am familiar with Python. Link for the repository: (let me know if this is the right way to upload it, I tried my best following your instructions)
# \
# https://github.com/pabloruizQC/MSE--HM1
