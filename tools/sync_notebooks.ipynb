# %%
# === Sync my MSE 510 notebooks from Google Drive into this repo ===
import os, re, shutil, subprocess, glob
from google.colab import drive
drive.mount('/content/drive')

TOKEN = os.environ.get("GH_TOKEN") or __import__("getpass").getpass("GitHub token (repo scope): ")
URL = f"https://pabloruizQC:{TOKEN}@github.com/pabloruizQC/MSE-510-Spring-2026.git"

WANTED = {
 "my-work/module-1-numerical-foundations/Homework_2.ipynb":            r"MSE\s*Homework_2",
 "my-work/module-2-symbolic-regression/Homework_4.ipynb":              r"Homework_4",
 "my-work/module-2-symbolic-regression/Hackathon_2_Symbolic_Regression.ipynb": r"hackaton_?02.?19",
 "my-work/module-3-differential-equations/Hackathon_3_Dynamics.ipynb": r"Hackaton\s*03.?04",
 "my-work/module-3-differential-equations/Midterm_1.ipynb":            r"Midterm_Spring2026",
 "my-work/module-4-physics-informed-ml/Hackathon_4_STM_Analysis.ipynb":r"STM hackathon",
 "my-work/module-5-bayesian-methods/Homework_7.ipynb":                 r"Pablo Homework_7",
 "my-work/module-5-bayesian-methods/Homework_9.ipynb":                 r"Homework_9",
 "my-work/module-6-gp-active-learning/Hackathon_5_Gaussian_Processes.ipynb": r"Hackathon.*familiar with GP",
 "my-work/module-6-gp-active-learning/Midterm_2_Part_I_Active_Learning.ipynb": r"MidTerm_Part_I",
 "my-work/module-6-gp-active-learning/Final_Active_Experimental_Design.ipynb": r"Final_Active_Experimental",
}

subprocess.run(["rm","-rf","/content/r"]); subprocess.run(["git","clone","--depth","1",URL,"/content/r"], check=True)
all_nb = glob.glob("/content/drive/MyDrive/**/*.ipynb", recursive=True)
print(f"{len(all_nb)} notebooks in Drive")
n=0
for dest, pat in WANTED.items():
    hits=[p for p in all_nb if re.search(pat, os.path.basename(p), re.I)]
    if hits:
        src=max(hits, key=os.path.getsize)
        os.makedirs(f"/content/r/{os.path.dirname(dest)}", exist_ok=True)
        shutil.copy(src, f"/content/r/{dest}"); n+=1
        print("OK ", dest, "<-", os.path.basename(src))
    else:
        print("NOT FOUND:", dest)
os.chdir("/content/r")
subprocess.run(["git","config","user.email","pruizcre@vols.utk.edu"])
subprocess.run(["git","config","user.name","Pablo Ruiz"])
subprocess.run(["git","add","-A"]); subprocess.run(["git","commit","-m",f"Add {n} solution notebooks from Colab"], check=False)
subprocess.run(["git","push"], check=True)
print(f"DONE: {n} notebooks pushed")
